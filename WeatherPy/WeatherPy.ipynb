# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
# !pip install citipy
from citipy import citipy
# Out:
# Requirement already satisfied: citipy in /opt/anaconda3/lib/python3.11/site-packages (0.0.6)
# Requirement already satisfied: kdtree>=0.12 in /opt/anaconda3/lib/python3.11/site-packages (from citipy) (0.16)

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 597

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f'https://api.openweathermap.org/data/2.5/weather?q='

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f'{city}&appid={weather_api_key}'

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(url+city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']-270
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        
        t = time.localtime(city_weather['dt'])
        t.tm_year
        t.tm_mon
        t.tm_yday
        # date = f'{t.tm_year}-{t.tm_mon}-{t.tm_yday}'
        city_date = f'{t.tm_year}-{t.tm_mon}-{t.tm_yday}'

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kuqa
# Processing Record 2 of Set 1 | namibe
# Processing Record 3 of Set 1 | fuvahmulah
# City not found. Skipping...
# Processing Record 4 of Set 1 | opuwo
# Processing Record 5 of Set 1 | puerto ayora
# Processing Record 6 of Set 1 | wenchang
# Processing Record 7 of Set 1 | waitangi
# Processing Record 8 of Set 1 | ust'-kulom
# Processing Record 9 of Set 1 | kingston
# Processing Record 10 of Set 1 | kearney
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | kachkanar
# Processing Record 14 of Set 1 | chonchi
# Processing Record 15 of Set 1 | port-aux-francais
# Processing Record 16 of Set 1 | pilar do sul
# Processing Record 17 of Set 1 | devinuwara
# City not found. Skipping...
# Processing Record 18 of Set 1 | kodiak
# Processing Record 19 of Set 1 | grytviken
# Processing Record 20 of Set 1 | stanley
# Processing Record 21 of Set 1 | dongning
# Processing Record 22 of Set 1 | adamstown
# Processing Record 23 of Set 1 | puerto natales
# Processing Record 24 of Set 1 | buala
# Processing Record 25 of Set 1 | albemarle
# Processing Record 26 of Set 1 | atafu village
# Processing Record 27 of Set 1 | avarua
# Processing Record 28 of Set 1 | ocean city
# Processing Record 29 of Set 1 | usogorsk
# Processing Record 30 of Set 1 | solleftea
# Processing Record 31 of Set 1 | hermanus
# Processing Record 32 of Set 1 | anadyr
# Processing Record 33 of Set 1 | hamilton
# Processing Record 34 of Set 1 | port elizabeth
# Processing Record 35 of Set 1 | palmer
# Processing Record 36 of Set 1 | berdigestyakh
# Processing Record 37 of Set 1 | bredasdorp
# Processing Record 38 of Set 1 | invercargill
# Processing Record 39 of Set 1 | nadym
# Processing Record 40 of Set 1 | uturoa
# Processing Record 41 of Set 1 | callao
# Processing Record 42 of Set 1 | brisas de zicatela
# Processing Record 43 of Set 1 | kisangani
# Processing Record 44 of Set 1 | colonia
# Processing Record 45 of Set 1 | papatowai
# Processing Record 46 of Set 1 | flin flon
# Processing Record 47 of Set 1 | karamay
# Processing Record 48 of Set 1 | haiku-pauwela
# Processing Record 49 of Set 1 | nova sintra
# Processing Record 50 of Set 1 | ambovombe
# Processing Record 0 of Set 2 | nizao
# Processing Record 1 of Set 2 | la passe
# Processing Record 2 of Set 2 | talnakh
# Processing Record 3 of Set 2 | kavieng
# Processing Record 4 of Set 2 | bilibino
# Processing Record 5 of Set 2 | bethel
# Processing Record 6 of Set 2 | upper hutt
# Processing Record 7 of Set 2 | flying fish cove
# Processing Record 8 of Set 2 | thompson
# Processing Record 9 of Set 2 | tambacounda
# Processing Record 10 of Set 2 | freetown
# Processing Record 11 of Set 2 | margaret river
# Processing Record 12 of Set 2 | albany
# Processing Record 13 of Set 2 | greenville
# Processing Record 14 of Set 2 | college
# Processing Record 15 of Set 2 | ilulissat
# Processing Record 16 of Set 2 | zaozersk
# Processing Record 17 of Set 2 | cadale
# Processing Record 18 of Set 2 | buckhannon
# Processing Record 19 of Set 2 | west island
# Processing Record 20 of Set 2 | ust-nera
# Processing Record 21 of Set 2 | selfoss
# Processing Record 22 of Set 2 | olonkinbyen
# Processing Record 23 of Set 2 | touros
# Processing Record 24 of Set 2 | ubari
# Processing Record 25 of Set 2 | santo antonio do ica
# Processing Record 26 of Set 2 | edinburgh of the seven seas
# Processing Record 27 of Set 2 | iglino
# Processing Record 28 of Set 2 | nchelenge
# Processing Record 29 of Set 2 | praia da vitoria
# Processing Record 30 of Set 2 | conception bay south
# Processing Record 31 of Set 2 | molochnoye
# Processing Record 32 of Set 2 | iqaluit
# Processing Record 33 of Set 2 | ribeira grande
# Processing Record 34 of Set 2 | medicine hat
# Processing Record 35 of Set 2 | queenstown
# Processing Record 36 of Set 2 | utrik
# Processing Record 37 of Set 2 | the pas
# Processing Record 38 of Set 2 | arafat
# Processing Record 39 of Set 2 | kirakat
# Processing Record 40 of Set 2 | saudarkrokur
# Processing Record 41 of Set 2 | lebu
# Processing Record 42 of Set 2 | temerluh
# Processing Record 43 of Set 2 | bahia honda
# Processing Record 44 of Set 2 | arraial do cabo
# Processing Record 45 of Set 2 | whitehorse
# Processing Record 46 of Set 2 | beyneu
# Processing Record 47 of Set 2 | aasiaat
# Processing Record 48 of Set 2 | klyuchi
# Processing Record 49 of Set 2 | lodwar
# Processing Record 0 of Set 3 | tripoli
# Processing Record 1 of Set 3 | maceio
# Processing Record 2 of Set 3 | blackmans bay
# Processing Record 3 of Set 3 | jamestown
# Processing Record 4 of Set 3 | morondava
# Processing Record 5 of Set 3 | fale old settlement
# Processing Record 6 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 7 of Set 3 | mitu
# Processing Record 8 of Set 3 | lukolela
# Processing Record 9 of Set 3 | daru
# Processing Record 10 of Set 3 | isafjordur
# Processing Record 11 of Set 3 | tyukhtet
# Processing Record 12 of Set 3 | longyearbyen
# Processing Record 13 of Set 3 | new norfolk
# Processing Record 14 of Set 3 | cromwell
# Processing Record 15 of Set 3 | falenki
# Processing Record 16 of Set 3 | maua
# Processing Record 17 of Set 3 | kruisfontein
# Processing Record 18 of Set 3 | ciudad lazaro cardenas
# Processing Record 19 of Set 3 | bartica
# Processing Record 20 of Set 3 | sitia
# Processing Record 21 of Set 3 | keflavik
# Processing Record 22 of Set 3 | siquirres
# Processing Record 23 of Set 3 | port mathurin
# Processing Record 24 of Set 3 | enewetak
# Processing Record 25 of Set 3 | alamosa
# Processing Record 26 of Set 3 | faya-largeau
# Processing Record 27 of Set 3 | qaqortoq
# Processing Record 28 of Set 3 | hiratacho
# Processing Record 29 of Set 3 | pont-l'abbe
# City not found. Skipping...
# Processing Record 30 of Set 3 | saipan
# Processing Record 31 of Set 3 | tarko-sale
# Processing Record 32 of Set 3 | antsiranana
# Processing Record 33 of Set 3 | mariental
# Processing Record 34 of Set 3 | kapuskasing
# Processing Record 35 of Set 3 | howard springs
# Processing Record 36 of Set 3 | kulhudhuffushi
# Processing Record 37 of Set 3 | mount gambier
# Processing Record 38 of Set 3 | carnarvon
# Processing Record 39 of Set 3 | ta`u
# Processing Record 40 of Set 3 | east end
# Processing Record 41 of Set 3 | puerto aysen
# Processing Record 42 of Set 3 | jaguarao
# Processing Record 43 of Set 3 | merizo village
# Processing Record 44 of Set 3 | montepuez
# Processing Record 45 of Set 3 | pirapozinho
# Processing Record 46 of Set 3 | lihue
# Processing Record 47 of Set 3 | fandriana
# Processing Record 48 of Set 3 | nizhnesortymskiy
# Processing Record 49 of Set 3 | djibo
# Processing Record 0 of Set 4 | tolanaro
# Processing Record 1 of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 2 of Set 4 | kristiansund
# Processing Record 3 of Set 4 | turkmenbasy
# Processing Record 4 of Set 4 | usinsk
# Processing Record 5 of Set 4 | cheremukhovo
# Processing Record 6 of Set 4 | kerema
# Processing Record 7 of Set 4 | piton saint-leu
# Processing Record 8 of Set 4 | kapa'a
# Processing Record 9 of Set 4 | princeton
# Processing Record 10 of Set 4 | saldanha
# Processing Record 11 of Set 4 | macau
# Processing Record 12 of Set 4 | badger
# Processing Record 13 of Set 4 | port alfred
# Processing Record 14 of Set 4 | thetford
# Processing Record 15 of Set 4 | kalmunai
# Processing Record 16 of Set 4 | chibougamau
# Processing Record 17 of Set 4 | hasaki
# Processing Record 18 of Set 4 | muzayri'
# City not found. Skipping...
# Processing Record 19 of Set 4 | vorkuta
# Processing Record 20 of Set 4 | port macquarie
# Processing Record 21 of Set 4 | midvagur
# Processing Record 22 of Set 4 | astrakhan
# Processing Record 23 of Set 4 | lata
# Processing Record 24 of Set 4 | ohara
# Processing Record 25 of Set 4 | carros
# Processing Record 26 of Set 4 | zaragoza
# Processing Record 27 of Set 4 | puerto deseado
# Processing Record 28 of Set 4 | pisco
# Processing Record 29 of Set 4 | cooper's town
# Processing Record 30 of Set 4 | svetlyy
# Processing Record 31 of Set 4 | sao joao da barra
# Processing Record 32 of Set 4 | afaahiti
# Processing Record 33 of Set 4 | tegina
# Processing Record 34 of Set 4 | ponta pora
# Processing Record 35 of Set 4 | sitka
# Processing Record 36 of Set 4 | tralee
# Processing Record 37 of Set 4 | udachny
# Processing Record 38 of Set 4 | puerto colombia
# Processing Record 39 of Set 4 | luderitz
# Processing Record 40 of Set 4 | kununurra
# Processing Record 41 of Set 4 | camarinas
# Processing Record 42 of Set 4 | ad dilam
# Processing Record 43 of Set 4 | tamandare
# Processing Record 44 of Set 4 | tibanbang
# Processing Record 45 of Set 4 | beau vallon
# Processing Record 46 of Set 4 | tazacorte
# Processing Record 47 of Set 4 | barcelos
# Processing Record 48 of Set 4 | kimbe
# Processing Record 49 of Set 4 | velingara
# Processing Record 0 of Set 5 | arkalyk
# Processing Record 1 of Set 5 | kolonia town
# Processing Record 2 of Set 5 | porthcawl
# Processing Record 3 of Set 5 | johi
# Processing Record 4 of Set 5 | mahibadhoo
# Processing Record 5 of Set 5 | karkira
# Processing Record 6 of Set 5 | cameron
# Processing Record 7 of Set 5 | kogalym
# Processing Record 8 of Set 5 | sao felix do xingu
# Processing Record 9 of Set 5 | sultanah
# Processing Record 10 of Set 5 | tamanrasset
# Processing Record 11 of Set 5 | goianesia
# Processing Record 12 of Set 5 | kishapu
# Processing Record 13 of Set 5 | wailua homesteads
# Processing Record 14 of Set 5 | buzdyak
# Processing Record 15 of Set 5 | la ronge
# Processing Record 16 of Set 5 | trincomalee
# Processing Record 17 of Set 5 | oranjemund
# Processing Record 18 of Set 5 | saint-pierre
# Processing Record 19 of Set 5 | pajara
# Processing Record 20 of Set 5 | egbe
# Processing Record 21 of Set 5 | nar'yan-mar
# Processing Record 22 of Set 5 | bonthe
# Processing Record 23 of Set 5 | kassala
# Processing Record 24 of Set 5 | mata-utu
# Processing Record 25 of Set 5 | sao paulo de olivenca
# Processing Record 26 of Set 5 | collie
# Processing Record 27 of Set 5 | polyarnyy
# Processing Record 28 of Set 5 | bereznik
# Processing Record 29 of Set 5 | umuahia
# Processing Record 30 of Set 5 | georgetown
# Processing Record 31 of Set 5 | cockburn town
# Processing Record 32 of Set 5 | vila do maio
# Processing Record 33 of Set 5 | bangassou
# Processing Record 34 of Set 5 | sinazongwe
# Processing Record 35 of Set 5 | tchaourou
# Processing Record 36 of Set 5 | margate
# Processing Record 37 of Set 5 | mountain home
# Processing Record 38 of Set 5 | miguel ahumada
# Processing Record 39 of Set 5 | kez
# Processing Record 40 of Set 5 | hilo
# Processing Record 41 of Set 5 | tiksi
# Processing Record 42 of Set 5 | san pedro
# Processing Record 43 of Set 5 | crane
# Processing Record 44 of Set 5 | 'alaqahdari dishu
# Processing Record 45 of Set 5 | gusinoozyorsk
# Processing Record 46 of Set 5 | aldama
# Processing Record 47 of Set 5 | dar naim
# City not found. Skipping...
# Processing Record 48 of Set 5 | coihueco
# Processing Record 49 of Set 5 | hammerfest
# Processing Record 0 of Set 6 | vorgashor
# Processing Record 1 of Set 6 | nelson bay
# Processing Record 2 of Set 6 | dalton
# Processing Record 3 of Set 6 | chiili
# City not found. Skipping...
# Processing Record 4 of Set 6 | suntar
# Processing Record 5 of Set 6 | constantia
# Processing Record 6 of Set 6 | taoudenni
# Processing Record 7 of Set 6 | amos
# Processing Record 8 of Set 6 | mamayvtsi
# City not found. Skipping...
# Processing Record 9 of Set 6 | petropavlovsk-kamchatsky
# Processing Record 10 of Set 6 | arzgir
# Processing Record 11 of Set 6 | grande prairie
# Processing Record 12 of Set 6 | fort mcmurray
# Processing Record 13 of Set 6 | cumbal
# Processing Record 14 of Set 6 | la ferte-bernard
# Processing Record 15 of Set 6 | tomatlan
# Processing Record 16 of Set 6 | cable beach
# City not found. Skipping...
# Processing Record 17 of Set 6 | nogliki
# Processing Record 18 of Set 6 | cannonvale
# Processing Record 19 of Set 6 | rio preto da eva
# Processing Record 20 of Set 6 | saint-joseph
# Processing Record 21 of Set 6 | namdrik
# Processing Record 22 of Set 6 | zintan
# Processing Record 23 of Set 6 | sibundoy
# Processing Record 24 of Set 6 | kuta
# Processing Record 25 of Set 6 | kidal
# Processing Record 26 of Set 6 | punta arenas
# Processing Record 27 of Set 6 | kralendijk
# Processing Record 28 of Set 6 | funafuti
# Processing Record 29 of Set 6 | kerikeri
# Processing Record 30 of Set 6 | sathupalli
# Processing Record 31 of Set 6 | okha
# Processing Record 32 of Set 6 | sanming
# Processing Record 33 of Set 6 | saint-philippe
# Processing Record 34 of Set 6 | rhinelander
# Processing Record 35 of Set 6 | rongelap
# Processing Record 36 of Set 6 | guerrero negro
# Processing Record 37 of Set 6 | eyl
# Processing Record 38 of Set 6 | mareeba
# Processing Record 39 of Set 6 | ibanda
# Processing Record 40 of Set 6 | sao vicente
# Processing Record 41 of Set 6 | letterkenny
# Processing Record 42 of Set 6 | cepu
# Processing Record 43 of Set 6 | howrah
# Processing Record 44 of Set 6 | sironj
# Processing Record 45 of Set 6 | tura
# Processing Record 46 of Set 6 | buon ma thuot
# Processing Record 47 of Set 6 | mount isa
# Processing Record 48 of Set 6 | athni
# Processing Record 49 of Set 6 | armacao de buzios
# Processing Record 0 of Set 7 | cabo san lucas
# Processing Record 1 of Set 7 | mejit
# Processing Record 2 of Set 7 | geraldton
# Processing Record 3 of Set 7 | kirensk
# Processing Record 4 of Set 7 | galesong
# Processing Record 5 of Set 7 | abancay
# Processing Record 6 of Set 7 | hawera
# Processing Record 7 of Set 7 | khovd
# Processing Record 8 of Set 7 | east london
# Processing Record 9 of Set 7 | rio grande
# Processing Record 10 of Set 7 | drummondville
# Processing Record 11 of Set 7 | kamyanyets
# Processing Record 12 of Set 7 | marshall
# Processing Record 13 of Set 7 | dwarka
# Processing Record 14 of Set 7 | golere
# Processing Record 15 of Set 7 | damghan
# Processing Record 16 of Set 7 | monrovia
# Processing Record 17 of Set 7 | moses lake
# Processing Record 18 of Set 7 | santa elena de uairen
# Processing Record 19 of Set 7 | aripuana
# Processing Record 20 of Set 7 | langepas
# Processing Record 21 of Set 7 | omdurman
# Processing Record 22 of Set 7 | nosy varika
# Processing Record 23 of Set 7 | mount pearl
# Processing Record 24 of Set 7 | wanning
# Processing Record 25 of Set 7 | chapaev
# Processing Record 26 of Set 7 | were ilu
# Processing Record 27 of Set 7 | bardai
# Processing Record 28 of Set 7 | tazovsky
# Processing Record 29 of Set 7 | aykhal
# Processing Record 30 of Set 7 | kone
# Processing Record 31 of Set 7 | puerto baquerizo moreno
# Processing Record 32 of Set 7 | sinmak
# Processing Record 33 of Set 7 | labrador city
# Processing Record 34 of Set 7 | oum hadjer
# Processing Record 35 of Set 7 | tarboro
# Processing Record 36 of Set 7 | egilsstadir
# Processing Record 37 of Set 7 | plakhtiyivka
# Processing Record 38 of Set 7 | akdepe
# Processing Record 39 of Set 7 | matadi
# Processing Record 40 of Set 7 | talcahuano
# Processing Record 41 of Set 7 | san patricio
# Processing Record 42 of Set 7 | jiuquan
# Processing Record 43 of Set 7 | mahajanga
# Processing Record 44 of Set 7 | christchurch
# Processing Record 45 of Set 7 | olyokminsk
# Processing Record 46 of Set 7 | horta
# Processing Record 47 of Set 7 | hargeysa
# Processing Record 48 of Set 7 | shingu
# Processing Record 49 of Set 7 | vilyuchinsk
# Processing Record 0 of Set 8 | la paz
# Processing Record 1 of Set 8 | tyumen
# Processing Record 2 of Set 8 | totness
# Processing Record 3 of Set 8 | yatou
# Processing Record 4 of Set 8 | minas de marcona
# Processing Record 5 of Set 8 | tadine
# Processing Record 6 of Set 8 | naze
# Processing Record 7 of Set 8 | labytnangi
# Processing Record 8 of Set 8 | nizhniy lomov
# Processing Record 9 of Set 8 | trinidad
# Processing Record 10 of Set 8 | awjilah
# Processing Record 11 of Set 8 | bikenibeu village
# Processing Record 12 of Set 8 | princeville
# Processing Record 13 of Set 8 | filey
# Processing Record 14 of Set 8 | sinan
# Processing Record 15 of Set 8 | sarpang
# Processing Record 16 of Set 8 | beatrice
# Processing Record 17 of Set 8 | hadibu
# Processing Record 18 of Set 8 | taltal
# Processing Record 19 of Set 8 | dudinka
# Processing Record 20 of Set 8 | monte alegre
# Processing Record 21 of Set 8 | lagoa
# Processing Record 22 of Set 8 | kayangel
# Processing Record 23 of Set 8 | talipparamba
# Processing Record 24 of Set 8 | hawaiian paradise park
# Processing Record 25 of Set 8 | lompoc
# Processing Record 26 of Set 8 | fuglafjordur
# Processing Record 27 of Set 8 | pechory
# Processing Record 28 of Set 8 | quellon
# Processing Record 29 of Set 8 | radevormwald
# Processing Record 30 of Set 8 | ponta delgada
# Processing Record 31 of Set 8 | walla walla
# Processing Record 32 of Set 8 | mirny
# Processing Record 33 of Set 8 | broken hill
# Processing Record 34 of Set 8 | beira
# Processing Record 35 of Set 8 | timimoun
# Processing Record 36 of Set 8 | portland
# Processing Record 37 of Set 8 | harstad
# Processing Record 38 of Set 8 | fort bragg
# Processing Record 39 of Set 8 | ketchikan
# Processing Record 40 of Set 8 | hithadhoo
# Processing Record 41 of Set 8 | kargasok
# Processing Record 42 of Set 8 | benjamin constant
# Processing Record 43 of Set 8 | coquimbo
# Processing Record 44 of Set 8 | burutu
# Processing Record 45 of Set 8 | plouzane
# Processing Record 46 of Set 8 | dzuunharaa
# Processing Record 47 of Set 8 | lianhe
# Processing Record 48 of Set 8 | mochudi
# Processing Record 49 of Set 8 | port lincoln
# Processing Record 0 of Set 9 | isna
# Processing Record 1 of Set 9 | kumla
# Processing Record 2 of Set 9 | kosh-agach
# Processing Record 3 of Set 9 | klishkivtsi
# Processing Record 4 of Set 9 | pen
# Processing Record 5 of Set 9 | sur
# Processing Record 6 of Set 9 | borujen
# Processing Record 7 of Set 9 | sandnessjoen
# Processing Record 8 of Set 9 | nagqu
# Processing Record 9 of Set 9 | west athens
# Processing Record 10 of Set 9 | mazagao
# Processing Record 11 of Set 9 | tobi village
# City not found. Skipping...
# Processing Record 12 of Set 9 | uray
# Processing Record 13 of Set 9 | abadiania
# Processing Record 14 of Set 9 | lawar khas
# Processing Record 15 of Set 9 | ko pha ngan
# Processing Record 16 of Set 9 | akureyri
# Processing Record 17 of Set 9 | farasan
# Processing Record 18 of Set 9 | thinadhoo
# Processing Record 19 of Set 9 | bayganin
# Processing Record 20 of Set 9 | lewiston orchards
# Processing Record 21 of Set 9 | mahina
# Processing Record 22 of Set 9 | iskateley
# Processing Record 23 of Set 9 | as sulayyil
# Processing Record 24 of Set 9 | vingt cinq
# City not found. Skipping...
# Processing Record 25 of Set 9 | uige
# Processing Record 26 of Set 9 | sarbogard
# Processing Record 27 of Set 9 | miandrivazo
# Processing Record 28 of Set 9 | viedma
# Processing Record 29 of Set 9 | jijiga
# Processing Record 30 of Set 9 | harnai
# Processing Record 31 of Set 9 | mossel bay
# Processing Record 32 of Set 9 | gaalkacyo
# Processing Record 33 of Set 9 | dunedin
# Processing Record 34 of Set 9 | novodvinsk
# Processing Record 35 of Set 9 | la sarre
# Processing Record 36 of Set 9 | stornoway
# Processing Record 37 of Set 9 | ati
# Processing Record 38 of Set 9 | yermolayevo
# Processing Record 39 of Set 9 | wajir
# Processing Record 40 of Set 9 | kedainiai
# Processing Record 41 of Set 9 | pandan
# Processing Record 42 of Set 9 | znamenskoye
# Processing Record 43 of Set 9 | dawson creek
# Processing Record 44 of Set 9 | vega de alatorre
# Processing Record 45 of Set 9 | san antonio de pale
# Processing Record 46 of Set 9 | den burg
# Processing Record 47 of Set 9 | timaru
# Processing Record 48 of Set 9 | pontarlier
# Processing Record 49 of Set 9 | karyes
# Processing Record 0 of Set 10 | dinajpur
# Processing Record 1 of Set 10 | belvedere marittimo
# Processing Record 2 of Set 10 | harper
# Processing Record 3 of Set 10 | puerto armuelles
# Processing Record 4 of Set 10 | cam ranh
# Processing Record 5 of Set 10 | debark'
# Processing Record 6 of Set 10 | pacific grove
# Processing Record 7 of Set 10 | lerwick
# Processing Record 8 of Set 10 | ha tien
# Processing Record 9 of Set 10 | nemuro
# Processing Record 10 of Set 10 | ploneour-lanvern
# Processing Record 11 of Set 10 | nicoya
# Processing Record 12 of Set 10 | khost
# Processing Record 13 of Set 10 | ocean pointe
# City not found. Skipping...
# Processing Record 14 of Set 10 | ascencion
# Processing Record 15 of Set 10 | rockport
# Processing Record 16 of Set 10 | nuuk
# Processing Record 17 of Set 10 | broome
# Processing Record 18 of Set 10 | at-bashi
# Processing Record 19 of Set 10 | xai-xai
# Processing Record 20 of Set 10 | kismayo
# Processing Record 21 of Set 10 | hayma'
# City not found. Skipping...
# Processing Record 22 of Set 10 | laascaanood
# Processing Record 23 of Set 10 | bayan nur
# City not found. Skipping...
# Processing Record 24 of Set 10 | birmingham
# Processing Record 25 of Set 10 | ancud
# Processing Record 26 of Set 10 | alofi
# Processing Record 27 of Set 10 | north tamworth
# Processing Record 28 of Set 10 | williams lake
# Processing Record 29 of Set 10 | puerto lopez
# Processing Record 30 of Set 10 | palikir - national government center
# Processing Record 31 of Set 10 | malazgirt
# Processing Record 32 of Set 10 | la gi
# Processing Record 33 of Set 10 | adilcevaz
# Processing Record 34 of Set 10 | brazzaville
# Processing Record 35 of Set 10 | pieksamaki
# Processing Record 36 of Set 10 | mola di bari
# Processing Record 37 of Set 10 | guelmim
# Processing Record 38 of Set 10 | north bend
# Processing Record 39 of Set 10 | ambon
# Processing Record 40 of Set 10 | yreka
# Processing Record 41 of Set 10 | tsiombe
# Processing Record 42 of Set 10 | tarawa
# Processing Record 43 of Set 10 | fortuna
# Processing Record 44 of Set 10 | plettenberg bay
# Processing Record 45 of Set 10 | ijuw
# City not found. Skipping...
# Processing Record 46 of Set 10 | namsos
# Processing Record 47 of Set 10 | kashmor
# Processing Record 48 of Set 10 | jauja
# Processing Record 49 of Set 10 | abadan
# Processing Record 0 of Set 11 | jeddah
# Processing Record 1 of Set 11 | aldinga beach
# Processing Record 2 of Set 11 | ghat
# Processing Record 3 of Set 11 | salalah
# Processing Record 4 of Set 11 | sao jose da coroa grande
# Processing Record 5 of Set 11 | remire-montjoly
# Processing Record 6 of Set 11 | an nuhud
# Processing Record 7 of Set 11 | luba
# Processing Record 8 of Set 11 | winters
# Processing Record 9 of Set 11 | gizo
# Processing Record 10 of Set 11 | mabaruma
# Processing Record 11 of Set 11 | gamboma
# Processing Record 12 of Set 11 | ayr
# Processing Record 13 of Set 11 | anton lizardo
# Processing Record 14 of Set 11 | bikin
# Processing Record 15 of Set 11 | pasni
# Processing Record 16 of Set 11 | port hedland
# Processing Record 17 of Set 11 | qazvin
# Processing Record 18 of Set 11 | zabol
# Processing Record 19 of Set 11 | peace river
# Processing Record 20 of Set 11 | coron
# Processing Record 21 of Set 11 | khandyga
# Processing Record 22 of Set 11 | qui nhon
# Processing Record 23 of Set 11 | santa terezinha
# Processing Record 24 of Set 11 | katlenburg-lindau
# Processing Record 25 of Set 11 | fomboni
# Processing Record 26 of Set 11 | dalandzadgad
# Processing Record 27 of Set 11 | guatrache
# Processing Record 28 of Set 11 | swan hill
# Processing Record 29 of Set 11 | weno
# Processing Record 30 of Set 11 | ghadamis
# Processing Record 31 of Set 11 | zhaodong
# Processing Record 32 of Set 11 | livadiya
# Processing Record 33 of Set 11 | hoxtolgay
# City not found. Skipping...
# Processing Record 34 of Set 11 | susuman
# Processing Record 35 of Set 11 | alenquer
# Processing Record 36 of Set 11 | karratha
# Processing Record 37 of Set 11 | zhezqazghan
# Processing Record 38 of Set 11 | magistral'nyy
# Processing Record 39 of Set 11 | zhumysker
# Processing Record 40 of Set 11 | itoman
# Processing Record 41 of Set 11 | holualoa
# Processing Record 42 of Set 11 | kudahuvadhoo
# Processing Record 43 of Set 11 | hondo
# Processing Record 44 of Set 11 | pointe michel
# Processing Record 45 of Set 11 | gulma
# Processing Record 46 of Set 11 | road town
# Processing Record 47 of Set 11 | shindand
# Processing Record 48 of Set 11 | mansfield
# Processing Record 49 of Set 11 | kodar
# Processing Record 0 of Set 12 | byaroza
# Processing Record 1 of Set 12 | safotu
# Processing Record 2 of Set 12 | charters towers
# Processing Record 3 of Set 12 | masterton
# Processing Record 4 of Set 12 | watford city
# Processing Record 5 of Set 12 | colonel hill
# Processing Record 6 of Set 12 | igarka
# Processing Record 7 of Set 12 | menongue
# Processing Record 8 of Set 12 | el-tor
# Processing Record 9 of Set 12 | deqen
# Processing Record 10 of Set 12 | lospalos
# Processing Record 11 of Set 12 | kurumkan
# Processing Record 12 of Set 12 | baikonur
# Processing Record 13 of Set 12 | zarah sharan
# Processing Record 14 of Set 12 | colchani
# Processing Record 15 of Set 12 | wagrowiec
# Processing Record 16 of Set 12 | gadzhiyevo
# Processing Record 17 of Set 12 | quiberon
# Processing Record 18 of Set 12 | troitskoye
# Processing Record 19 of Set 12 | hami
# Processing Record 20 of Set 12 | wloszczowa
# Processing Record 21 of Set 12 | minab
# Processing Record 22 of Set 12 | sabha
# Processing Record 23 of Set 12 | tranovaho
# City not found. Skipping...
# Processing Record 24 of Set 12 | wolmaransstad
# Processing Record 25 of Set 12 | bafoulabe
# Processing Record 26 of Set 12 | luckau
# Processing Record 27 of Set 12 | laojunmiao
# Processing Record 28 of Set 12 | galle
# Processing Record 29 of Set 12 | siwa oasis
# Processing Record 30 of Set 12 | nema
# Processing Record 31 of Set 12 | labuan bajo
# Processing Record 32 of Set 12 | st. john's
# Processing Record 33 of Set 12 | happy valley-goose bay
# Processing Record 34 of Set 12 | bandon
# Processing Record 35 of Set 12 | cidreira
# Processing Record 36 of Set 12 | la'ie
# Processing Record 37 of Set 12 | domerat
# Processing Record 38 of Set 12 | fisterra
# Processing Record 39 of Set 12 | lorgues
# Processing Record 40 of Set 12 | kinston
# Processing Record 41 of Set 12 | jayapura
# Processing Record 42 of Set 12 | greymouth
# Processing Record 43 of Set 12 | longwy
# Processing Record 44 of Set 12 | yurty
# Processing Record 45 of Set 12 | inhambane
# Processing Record 46 of Set 12 | riberalta
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          579
# Lat           579
# Lng           579
# Max Temp      579
# Humidity      579
# Cloudiness    579
# Wind Speed    579
# Country       579
# Date          579
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          kuqa  41.7278   82.9364     -3.48        68           3
# 1        namibe -15.1961   12.1522     22.91        86           7
# 2         opuwo -18.0607   13.8400     23.38        46          87
# 3  puerto ayora  -0.7393  -90.3518     27.34        96          79
# 4      wenchang  30.9040  118.4887      7.59        23           0
#
#    Wind Speed Country      Date
# 0        1.49      CN  2025-1-9
# 1        1.22      AO  2025-1-9
# 2        1.37      NA  2025-1-9
# 3        0.89      EC  2025-1-9
# 4        2.00      CN  2025-1-9

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv('../output_data/cities.csv', index_col="City_ID")
#/Users/lauraleecallahan/Desktop/python-api-challenge/python-api-challenge/output_data/cities.csv
# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                kuqa  41.7278   82.9364     -3.48        68           3
# 1              namibe -15.1961   12.1522     22.91        86           7
# 2               opuwo -18.0607   13.8400     23.38        46          87
# 3        puerto ayora  -0.7393  -90.3518     27.34        96          79
# 4            wenchang  30.9040  118.4887      7.59        23           0
#
#          Wind Speed Country      Date
# City_ID
# 0              1.49      CN  2025-1-9
# 1              1.22      AO  2025-1-9
# 2              1.37     NaN  2025-1-9
# 3              0.89      EC  2025-1-9
# 4              2.00      CN  2025-1-9

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
#add date to title

t = time.localtime()
t.tm_year
t.tm_mon
t.tm_yday
date = f'{t.tm_year}-{t.tm_mon}-{t.tm_yday}'
date = city_data_df['Date'][0]

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot.scatter(x='Lat', y='Max Temp', s=40, edgecolors='black', alpha=.86)
# plt.plot(marker='o',markerfacecolor='w', markeredgewidth=10.5, markeredgecolor=('black'))
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.title(f'City Max Latitude vs. Temperature ({date})')
plt.grid(visible=True)


# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot.scatter(x='Lat', y='Humidity', s=40, edgecolors='black', alpha=.86)
# plt.plot(marker='o',markerfacecolor='w', markeredgewidth=10.5, markeredgecolor=('black'))
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'City Latitude vs. Humidity ({date})')
plt.grid(visible=True)


# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot.scatter(x='Lat', y='Cloudiness', s=40, edgecolors='black', alpha=.90)
# plt.plot(marker='o',markerfacecolor='w', markeredgewidth=10.5, markeredgecolor=('black'))
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'City Max Latitude vs. Cloudiness ({date})')
plt.grid(visible=True)

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot.scatter(x='Lat', y='Wind Speed', s=40, edgecolors='black', alpha=.90)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title(f'City Max Latitude vs. Wind Speed ({date})')
plt.grid(visible=True)


# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def lin_reg(x,y):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = (x * slope) + intercept
    return regress_values, slope, intercept, rvalue

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              kuqa  41.7278   82.9364     -3.48        68           3
# 4          wenchang  30.9040  118.4887      7.59        23           0
# 6        ust'-kulom  61.6864   53.6902     -5.60        83          41
# 7          kingston  17.9970  -76.7936     28.68        83          20
# 8           kearney  40.6995  -99.0815      0.55        84           0
#
#          Wind Speed Country      Date
# City_ID
# 0              1.49      CN  2025-1-9
# 4              2.00      CN  2025-1-9
# 6              5.50      RU  2025-1-9
# 7              3.60      JM  2025-1-9
# 8              7.20      US  2025-1-9

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1              namibe -15.1961   12.1522     22.91        86           7
# 2               opuwo -18.0607   13.8400     23.38        46          87
# 3        puerto ayora  -0.7393  -90.3518     27.34        96          79
# 5            waitangi -43.9535 -176.5597     16.94        68          84
# 10            ushuaia -54.8000  -68.3000      7.97        89          26
#
#          Wind Speed Country      Date
# City_ID
# 1              1.22      AO  2025-1-9
# 2              1.37     NaN  2025-1-9
# 3              0.89      EC  2025-1-9
# 5              5.36      NZ  2025-1-9
# 10             1.76      AR  2025-1-9

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
northern_hemi_df.plot.scatter(x='Lat', y='Max Temp', s=40)

x=northern_hemi_df['Lat']
y=northern_hemi_df['Max Temp']
(regress_values, slope, intercept, rvalue) = lin_reg(x,y)

slope = '%.2f'%slope
intercept = '%.2f'%intercept
plt.text(2, -30, f'y = {slope}x + {intercept}', fontsize = 15, color='red')

print(f'The r-value is: {rvalue}')

plt.plot(x,regress_values, 'r-')
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.show()
# Out:
# The r-value is: -0.8606961269587691

# %%
# Linear regression on Southern Hemisphere
southern_hemi_df.plot.scatter(x='Lat', y='Max Temp', s=40)

x=southern_hemi_df['Lat']
y=southern_hemi_df['Max Temp']
(regress_values, slope, intercept, rvalue) = lin_reg(x,y)
plt.plot(x,regress_values, 'r-')


slope = '%.2f'%slope
intercept = '%.2f'%intercept
plt.text(-55, 35, f'y = {slope}x + {intercept}', fontsize = 15, color='red')

print(f'The r-value is: {rvalue}')

plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.show()
# Out:
# The r-value is: 0.5089341539930765

# %% [markdown]
# **Discussion about the linear relationship:** There is a linear correlation between your proximity to the equator and the max temperature of a region. The farther you move away from the equator the colder it can potentially get.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
northern_hemi_df.plot.scatter(x='Lat', y='Humidity', s=40)

x=northern_hemi_df['Lat']
y=northern_hemi_df['Humidity']
(regress_values, slope, intercept, rvalue) = lin_reg(x,y)
plt.plot(x,regress_values, 'r-')

slope = '%.2f'%slope
intercept = '%.2f'%intercept
plt.text(41, 10, f'y = {slope}x + {intercept}', fontsize = 15, color='red')

print(f'The r-value is: {rvalue}')

plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()
# Out:
# The r^2-value is: 0.007659599322853922

# %%
# Southern Hemisphere
southern_hemi_df.plot.scatter(x='Lat', y='Humidity')

x=southern_hemi_df['Lat']
y=southern_hemi_df['Humidity']
(regress_values, slope, intercept, rvalue) = lin_reg(x,y)
plt.plot(x,regress_values, 'r-')

slope = '%.2f'%slope
intercept = '%.2f'%intercept
plt.text(-53, 20, f'y = {slope}x + {intercept}', fontsize = 15, color='red')

print(f'The r-value is: {rvalue}')

plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()
# Out:
# The r-value is: 0.28290898758084876

# %% [markdown]
# **Discussion about the linear relationship:** Humidity increases with latitude. Northern hemisphere locations experience higher levels of humidity.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
northern_hemi_df.plot.scatter(x='Lat', y='Cloudiness')

x=northern_hemi_df['Lat']
y=northern_hemi_df['Cloudiness']
(regress_values, slope, intercept, rvalue) = lin_reg(x,y)
plt.plot(x,regress_values, 'r-')

slope = '%.2f'%slope
intercept = '%.2f'%intercept
plt.text(39, 10, f'y = {slope}x + {intercept}', fontsize = 15, color='red')

print(f'The r-value is: {rvalue}')

plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()
# Out:
# The r-value is: 0.3078032063935635

# %%
# Southern Hemisphere
southern_hemi_df.plot.scatter(x='Lat', y='Cloudiness', s=40)

x=southern_hemi_df['Lat']
y=southern_hemi_df['Cloudiness']
(regress_values, slope, intercept, rvalue) = lin_reg(x,y)
plt.plot(x,regress_values, 'r-')

slope = '%.2f'%slope
intercept = '%.2f'%intercept
plt.text(-25, 22, f'y = {slope}x + {intercept}', fontsize = 15, color='red')

print(f'The r-value is: {rvalue}')

plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()
# Out:
# The r^2-value is: 0.018616831531634456

# %% [markdown]
# **Discussion about the linear relationship:** Cloudiness increases with latitude. Similar to humidity.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
northern_hemi_df.plot.scatter(x='Lat', y='Wind Speed', s=40)

x=northern_hemi_df['Lat']
y=northern_hemi_df['Wind Speed']
(regress_values, slope, intercept, rvalue) = lin_reg(x,y)
plt.plot(x,regress_values, 'r-')

slope = '%.2f'%slope
intercept = '%.2f'%intercept
plt.text(0, 17, f'y = {slope}x + {intercept}', fontsize = 15, color='red')

print(f'The r-value is: {rvalue}')

plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()
# Out:
# The r-value is: 0.04306054274923207

# %%
# Southern Hemisphere
southern_hemi_df.plot.scatter(x='Lat', y='Wind Speed', s=40)

x=southern_hemi_df['Lat']
y=southern_hemi_df['Wind Speed']
(regress_values, slope, intercept, rvalue) = lin_reg(x,y)
plt.plot(x,regress_values, 'r-')

slope = '%.2f'%slope
intercept = '%.2f'%intercept
plt.text(-25, 10, f'y = {slope}x + {intercept}', fontsize = 15, color='red')

print(f'The r-value is: {rvalue}')

plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()
# Out:
# The r-value is: -0.1951508105564074

# %% [markdown]
# **Discussion about the linear relationship:** The farther you move away from the equator, the higher the wind speed.
